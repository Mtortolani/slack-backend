# %%
from spark_queries import SparkQuery
from mongo_queries import MongoSearch
from profiler import Profiler
import matplotlib.pyplot as plt

MQ = MongoSearch()
SQ = SparkQuery()
PF = Profiler()

# %%
data_randomUsersIds = PF.collect_performance_data_fixed_iters(MQ.randomUsersIds, SQ.randomUsersIds)
print(1)
data_randomWorkspaceIds = PF.collect_performance_data_fixed_iters(MQ.randomWorkspaceIds, SQ.randomWorkspaceIds)
print(2)
user_ids = MQ.randomUsersIds(10)
data_workspaceByUser = PF.collect_performance_data_fixed_iters(lambda: MQ.workspaceByUser(user_ids[0]), lambda: SQ.workspaceByUser(user_ids[0]))
print(3)
# Out:
# running
# running
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "C:\Users\mtort\AppData\Local\Programs\Python\Python39\lib\site-packages\py4j\java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "C:\Users\mtort\AppData\Local\Programs\Python\Python39\lib\site-packages\py4j\java_gateway.py", line 1217, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "C:\Users\mtort\AppData\Local\Programs\Python\Python39\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32748/339962156.py in <module>
# ----> 1 data_randomUsersIds = PF.collect_performance_data_fixed_iters(MQ.randomUsersIds, SQ.randomUsersIds)
#       2 print(1)
#       3 data_randomWorkspaceIds = PF.collect_performance_data_fixed_iters(MQ.randomWorkspaceIds, SQ.randomWorkspaceIds)
#       4 print(2)
#       5 user_ids = MQ.randomUsersIds(10)
#
# c:\Users\mtort\Repositories\classes\DS4300 Homework\slack-backend\profiler.py in collect_performance_data_fixed_iters(self, function1, function2, iterations)
#     122             print('running')
#     123
# --> 124     start_time = time.time()
#     125     for i in range(iterations):
#     126         print(function2())
#
# c:\Users\mtort\Repositories\classes\DS4300 Homework\slack-backend\spark_queries.py in randomUsersIds(self, count)
#      52                     Order By RAND()
#      53                     LIMIT {count}''')
# ---> 54         user_id = [df.collect()[i][0] for i in range(df.count())]
#      55         return user_id
#      56
#
# ~\Spark\spark-3.1.3-bin-hadoop3.2\python\pyspark\sql\dataframe.py in count(self)
#     662         2
#     663         """
# --> 664         return int(self._jdf.count())
#     665
#     666     def collect(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\py4j\java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\py4j\java_gateway.py in send_command(self, command)
#    1215
#    1216         try:
# -> 1217             answer = smart_decode(self.stream.readline()[:-1])
#    1218             logger.debug("Answer received: {0}".format(answer))
#    1219             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
data_workspaceByUser
# Out:
# {'mongo_c': array([0.00100017, 0.00200105, 0.00200725, 0.00200105, 0.00100255,
#         0.00199986, 0.00200391, 0.00092888, 0.00300026, 0.00099969,
#         0.01035023, 0.00046134, 0.00500226, 0.00105858, 0.00310636,
#         0.00099778, 0.00099945, 0.00299931, 0.00101519, 0.00307512,
#         0.00099945, 0.00299191, 0.00100207, 0.00101519, 0.00107932,
#         0.00976181, 0.00200653, 0.00099802, 0.00200272, 0.00102973,
#         0.00201488, 0.00200176, 0.00100803, 0.00300264, 0.00107241,
#         0.        , 0.00298214, 0.00103617, 0.00091243, 0.00186753,
#         0.01099586, 0.00499463, 0.00200391, 0.00300169, 0.00500393,
#         0.00092936, 0.00118995, 0.00099993, 0.00103521, 0.00399399,
#         0.0010066 , 0.00299692, 0.00200272, 0.00091362, 0.00299716,
#         0.01199937, 0.00300026, 0.00099921, 0.00407219, 0.00107408,
#         0.15665698, 0.14100099, 0.17108178, 0.14136362, 0.1215024 ,
#         0.16781259, 0.12698054, 0.16351843, 0.13324952, 0.17390752,
#         0.15717363, 0.15658498, 0.13092279, 0.16983557, 0.15512609,
#         0.14198661, 0.13602376, 0.16908526, 0.15900302, 0.13859391,
#         0.16264009, 0.16808629, 0.12172914, 0.15694785, 0.15292382,
#         0.15610576, 0.15952206, 0.14121842, 0.14132214, 0.15500903,
#         0.14302683, 0.13883519, 0.13853359, 0.17487574, 0.13949776,
#         0.13200283, 0.13798451, 0.13300133, 0.16259837, 0.15310764,
#         0.15994382, 0.12752771, 0.15122342, 0.13997364, 0.12167478,
#         0.12255406, 0.15873432, 0.12428641, 0.15309   , 0.16000009,
#         0.14697766, 0.13802767, 0.14355278, 0.15862155, 0.13570333,
#         0.14189839, 0.15157628, 0.1269989 , 0.16091585, 0.17401838,
#         0.19240761, 0.18662238, 0.25999999, 0.245996  , 0.27199149]),
#  'spark_i': array([ 4.31636572e-01, -2.09637403e-01,  1.49984360e-02,  1.58963203e-02,
#         -2.44662762e-02, -3.89184952e-02, -1.64403915e-02,  1.89294815e-02,
#         -3.87394428e-02, -1.17261410e-02, -1.04172230e-02,  2.65169144e-02,
#         -1.97203159e-02,  1.93657875e-02, -4.38070297e-03,  1.82709694e-02,
#          1.69706345e-02, -3.40213776e-02, -1.41294003e-02,  3.02586555e-02,
#          5.21802902e-03, -7.48586655e-03, -1.28667355e-02, -2.53870487e-02,
#          3.90126705e-02, -1.94978714e-02,  5.92827797e-03,  2.55441666e-03,
#         -2.99024582e-03, -1.94125175e-02,  1.26264095e-02, -2.46901512e-02,
#          3.28078270e-02, -5.82933426e-04, -1.69172287e-02,  1.80933475e-02,
#         -1.56559944e-02,  3.00807953e-02, -2.97181606e-02, -1.98612213e-02,
#          4.63101864e-02, -4.08320427e-02,  3.65378857e-02, -3.02689075e-02,
#          4.06579971e-02, -1.67338848e-02, -5.88655472e-04, -2.56621838e-02,
#          3.89127731e-02, -1.47094727e-02, -1.31394863e-02, -5.96284866e-03,
#          3.30615044e-02, -1.00822449e-02, -2.04091072e-02,  2.40461826e-02,
#          5.44619560e-03, -4.63571548e-02,  3.52187157e-02, -4.02402878e-03,
#          3.18193436e-03,  3.41629982e-03, -1.83036327e-02,  1.03712082e-04,
#          1.36868954e-02, -1.19822025e-02, -4.19163704e-03, -3.01599503e-04,
#          3.63421440e-02, -3.53779793e-02, -7.49492645e-03,  5.98168373e-03,
#         -4.98318672e-03,  2.95970440e-02, -9.49072838e-03,  6.83617592e-03,
#         -3.24161053e-02,  2.36957073e-02, -1.12497807e-02, -1.82988644e-02,
#          8.79287720e-04,  3.61802578e-02, -3.44479084e-02,  2.88035870e-02,
#          6.91008568e-03, -1.30224228e-02, -8.94999504e-03,  5.52511215e-03,
#          1.50687695e-02, -2.29182243e-02,  6.19506836e-03,  9.67788696e-03,
#         -2.45773792e-02,  3.39169502e-02,  1.31025314e-02,  1.83892250e-02,
#         -5.78522682e-03,  7.33776093e-02, -1.40039921e-02,  2.59954929e-02])}

# %%
mongo_data = fixed_data['mongo_i']
plt.plot(list(range(1,len(mongo_data)+1)), mongo_data)

# %%
spark_data = fixed_data['spark_c']
plt.plot(list(range(1,len(spark_data)+1)), spark_data)
